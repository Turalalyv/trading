# %%
import pandas as pd
from datetime import datetime,timedelta

# %%
# Open the file and read it line by line
file_path = "annual1.txt"
data_list = []  # List to hold dictionaries

with open(file_path, "r") as file:
    # Read the first line, strip quotes from headers, and split by commas
    header = [col.strip('"') for col in file.readline().strip().split(",")]
    
    # Process each subsequent line
    for line in file:
        # Split the line by commas and strip quotes from each value
        values = [value.strip('"') for value in line.strip().split(",")]
        
        # Create a dictionary for the row
        row_dict = dict(zip(header, values))
        
        # Append the dictionary to the list
        data_list.append(row_dict)
    
df=pd.DataFrame(data_list)

columns=['Market and Exchange Names',
'As of Date in Form YYYY-MM-DD','Open Interest (All)',
'Noncommercial Positions-Long (All)',
'Noncommercial Positions-Short (All)',
'Commercial Positions-Long (All)',
'Commercial Positions-Short (All)',
' Total Reportable Positions-Long (All)',
'Total Reportable Positions-Short (All)',
'Nonreportable Positions-Long (All)',
'Nonreportable Positions-Short (All)',
'Change in Open Interest (All)',
'Change in Noncommercial-Long (All)',
'Change in Noncommercial-Short (All)',
'Change in Noncommercial-Spreading (All)',
'Change in Commercial-Long (All)',
'Change in Commercial-Short (All)',
'Change in Total Reportable-Long (All)',
'Change in Total Reportable-Short (All)',
'Change in Nonreportable-Long (All)',
'Change in Nonreportable-Short (All)']
df=df[columns]
df=df.reset_index(drop=True)

df['As of Date in Form YYYY-MM-DD'] = pd.to_datetime(df['As of Date in Form YYYY-MM-DD'], dayfirst=True, errors='coerce')
for i in df.columns[2:]:
    # print(i)
    df[i] = pd.to_numeric(df[i], errors='coerce').astype('Int64') 

# col_dict={
#     'Noncommercial':['Noncommercial Positions-Long (All)','Noncommercial Positions-Short (All)'],
#     'Commercial':['Commercial Positions-Long (All)','Commercial Positions-Short (All)'],
#     'Total Reportable':[' Total Reportable Positions-Long (All)','Total Reportable Positions-Short (All)'],
#     'Nonreportable':['Nonreportable Positions-Long (All)','Nonreportable Positions-Short (All)']}

col_dict={
    'Noncommercial':['Change in Noncommercial-Long (All)','Change in Noncommercial-Short (All)'],
    'Commercial':['Change in Commercial-Long (All)', 'Change in Commercial-Short (All)']}

for a, b in col_dict.items():
    df[f'{a}_net_positions'] = df[b[0]] - df[b[1]]
df.fillna(0,inplace=True)

def generate_market_signals(df):
    """
    Analyzes market positions of Non-Commercials (speculators) and Commercials (hedgers)
    to generate trading signals.

    Parameters:
    df (DataFrame): DataFrame containing columns:
        - 'Market and Exchange Names'
        - 'As of Date in Form YYYY-MM-DD'
        - 'Noncommercial_net_positions'
        - 'Commercial_net_positions'

    Returns:
    DataFrame: Original DataFrame with an additional 'Market_Signal' column
    indicating 'Bullish', 'Bearish', or 'Neutral' signal.
    """
    def determine_signal(non_com, com):
        if non_com > 0 and com < 0:
            return 'Bullish'
        elif non_com < 0 and com > 0:
            return 'Bearish'
        else:
            return 'Neutral'
    
    # Apply the signal determination function
    df['Market_Signal'] = df.apply(
        lambda row: determine_signal(
            row['Noncommercial_net_positions'], 
            row['Commercial_net_positions']
        ), axis=1
    )
    
    return df

updated_df = generate_market_signals(df)

# Display the DataFrame with signals
# print(updated_df[['Market and Exchange Names', 'As of Date in Form YYYY-MM-DD', 'Market_Signal']])

updated_df=updated_df[['Market and Exchange Names', 'As of Date in Form YYYY-MM-DD','Noncommercial_net_positions','Commercial_net_positions','Market_Signal']]

updated_df['As of Date in Form YYYY-MM-DD']=pd.to_datetime(updated_df['As of Date in Form YYYY-MM-DD'])

updated_df=updated_df[updated_df['As of Date in Form YYYY-MM-DD']>datetime.now()-timedelta(days=15)]

target_strings = [
    'DOLLAR', 'SILVER', 'GOLD', 'POUND', 'FRANC', 'USD INDEX', 'EURO FX', 
    'JAPANESE YEN', 'DOW JONES', 'BITCOIN', 'S&P 500', 'ETHER', 'DOGECOIN', 
    'NASDAQ', 'NIKKEI', 'OIL'
]

filtered_df = updated_df[updated_df.iloc[:, 0].apply(lambda x: any(target_string in str(x) for target_string in target_strings))]

filtered_df=filtered_df.reset_index(drop=True).sort_values(by='Noncommercial_net_positions')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5340\457647230.py:45: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['As of Date in Form YYYY-MM-DD'] = pd.to_datetime(df['As of Date in Form YYYY-MM-DD'], dayfirst=True, errors='coerce')
# C:\Users\user\AppData\Local\Temp\ipykernel_5340\457647230.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.fillna(0,inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_5340\457647230.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_df['As of Date in Form YYYY-MM-DD']=pd.to_datetime(updated_df['As of Date in Form YYYY-MM-DD'])

# %%
updated_df
# Out:
#                                Market and Exchange Names  \
# 0                     WHEAT-SRW - CHICAGO BOARD OF TRADE
# 47                    WHEAT-HRW - CHICAGO BOARD OF TRADE
# 94           WHEAT-HRSpring - MINNEAPOLIS GRAIN EXCHANGE
# 141                        CORN - CHICAGO BOARD OF TRADE
# 188                        OATS - CHICAGO BOARD OF TRADE
# ...                                                  ...
# 14554  S&P 500 ANNUAL DIVIDEND INDEX - CHICAGO MERCAN...
# 14601  S&P 500 QUARTERLY DIVIDEND IND - CHICAGO MERCA...
# 14637  GULF JET NY HEAT OIL SPR - NEW YORK MERCANTILE...
# 14684  MARINE .5% FOB USGC/BRENT 1st - ICE FUTURES EN...
# 14731  GULF # 6 FUEL OIL CRACK - NEW YORK MERCANTILE ...
#
#       As of Date in Form YYYY-MM-DD  Noncommercial_net_positions  \
# 0                        2024-11-19                        -7510
# 47                       2024-11-19                          560
# 94                       2024-11-19                        -6200
# 141                      2024-11-19                       -14345
# 188                      2024-11-19                         -305
# ...                             ...                          ...
# 14554                    2024-11-19                         -336
# 14601                    2024-11-19                         -202
# 14637                    2024-11-19                          150
# 14684                    2024-11-19                           13
# 14731                    2024-11-19                         -480
#
#        Commercial_net_positions Market_Signal
# 0                          6614       Bearish
# 47                        -2991       Bullish
# 94                         5892       Bearish
# 141                       12969       Bearish
# 188                         116       Bearish
# ...                         ...           ...
# 14554                        89       Bearish
# 14601                       202       Bearish
# 14637                      -150       Bullish
# 14684                       -13       Bullish
# 14731                       480       Bearish
#
# [325 rows x 5 columns]

# %%
#---------------------------------------------------------------------------------------

# %%
file_path = "annual1.txt"
data_list = []  # List to hold dictionaries

with open(file_path, "r") as file:
    # Read the first line, strip quotes from headers, and split by commas
    header = [col.strip('"') for col in file.readline().strip().split(",")]
    
    # Process each subsequent line
    for line in file:
        # Split the line by commas and strip quotes from each value
        values = [value.strip('"') for value in line.strip().split(",")]
        
        # Create a dictionary for the row
        row_dict = dict(zip(header, values))
        
        # Append the dictionary to the list
        data_list.append(row_dict)
    
df=pd.DataFrame(data_list)

columns=['Market and Exchange Names',
'As of Date in Form YYYY-MM-DD','Open Interest (All)',
'Noncommercial Positions-Long (All)',
'Noncommercial Positions-Short (All)',
'Commercial Positions-Long (All)',
'Commercial Positions-Short (All)',
' Total Reportable Positions-Long (All)',
'Total Reportable Positions-Short (All)',
'Nonreportable Positions-Long (All)',
'Nonreportable Positions-Short (All)',
'Change in Open Interest (All)',
'Change in Noncommercial-Long (All)',
'Change in Noncommercial-Short (All)',
'Change in Noncommercial-Spreading (All)',
'Change in Commercial-Long (All)',
'Change in Commercial-Short (All)',
'Change in Total Reportable-Long (All)',
'Change in Total Reportable-Short (All)',
'Change in Nonreportable-Long (All)',
'Change in Nonreportable-Short (All)']
df=df[columns]
df=df.reset_index(drop=True)

df['As of Date in Form YYYY-MM-DD'] = pd.to_datetime(df['As of Date in Form YYYY-MM-DD'], dayfirst=True, errors='coerce')
for i in df.columns[2:]:
    # print(i)
    df[i] = pd.to_numeric(df[i], errors='coerce').astype('Int64') 

# col_dict={
#     'Noncommercial':['Noncommercial Positions-Long (All)','Noncommercial Positions-Short (All)'],
#     'Commercial':['Commercial Positions-Long (All)','Commercial Positions-Short (All)'],
#     'Total Reportable':[' Total Reportable Positions-Long (All)','Total Reportable Positions-Short (All)'],
#     'Nonreportable':['Nonreportable Positions-Long (All)','Nonreportable Positions-Short (All)']}

col_dict={
    'Noncommercial':['Change in Noncommercial-Long (All)','Change in Noncommercial-Short (All)'],
    'Commercial':['Change in Commercial-Long (All)', 'Change in Commercial-Short (All)']}

for a, b in col_dict.items():
    df[f'{a}_net_positions'] = df[b[0]] - df[b[1]]
df.fillna(0,inplace=True)

df['As of Date in Form YYYY-MM-DD']=pd.to_datetime(df['As of Date in Form YYYY-MM-DD'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8932\1622252650.py:44: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['As of Date in Form YYYY-MM-DD'] = pd.to_datetime(df['As of Date in Form YYYY-MM-DD'], dayfirst=True, errors='coerce')
# C:\Users\user\AppData\Local\Temp\ipykernel_8932\1622252650.py:61: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.fillna(0,inplace=True)

# %%
df=df[['Market and Exchange Names', 'As of Date in Form YYYY-MM-DD','Noncommercial_net_positions','Commercial_net_positions']].sort_values(by='As of Date in Form YYYY-MM-DD')

# %%
df=df[df['As of Date in Form YYYY-MM-DD']>datetime.now()-timedelta(days=60)]

# %%
target_strings = [
    'DOLLAR', 'SILVER', 'GOLD', 'POUND', 'FRANC', 'USD INDEX', 'EURO FX', 
    'JAPANESE YEN', 'DOW JONES', 'BITCOIN', 'S&P 500', 'ETHER', 'DOGECOIN', 
    'NASDAQ', 'NIKKEI', 'OIL'
]

df = df[df.iloc[:, 0].apply(lambda x: any(target_string in str(x) for target_string in target_strings))]

# %%
df=df.sort_values(by=['Market and Exchange Names','As of Date in Form YYYY-MM-DD']).reset_index(drop=True)

# %%
df.iloc[:,0].value_counts()
# Out:
# Market and Exchange Names
# ADJUSTED INT RATE S&P 500 TOTL - CHICAGO MERCANTILE EXCHANGE    7
# NZ DOLLAR - CHICAGO MERCANTILE EXCHANGE                         7
# MICRO ETHER - CHICAGO MERCANTILE EXCHANGE                       7
# MICRO GOLD - COMMODITY EXCHANGE INC.                            7
# NANO ETHER - LMX LABS LLC                                       7
# NASDAQ MINI - CHICAGO MERCANTILE EXCHANGE                       7
# NASDAQ-100 Consolidated - CHICAGO MERCANTILE EXCHANGE           7
# NIKKEI STOCK AVERAGE YEN DENOM - CHICAGO MERCANTILE EXCHANGE    7
# S&P 500 ANNUAL DIVIDEND INDEX - CHICAGO MERCANTILE EXCHANGE     7
# AUSTRALIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE                 7
# S&P 500 Consolidated - CHICAGO MERCANTILE EXCHANGE              7
# S&P 500 QUARTERLY DIVIDEND IND - CHICAGO MERCANTILE EXCHANGE    7
# SILVER - COMMODITY EXCHANGE INC.                                7
# SOYBEAN OIL - CHICAGO BOARD OF TRADE                            7
# SWISS FRANC - CHICAGO MERCANTILE EXCHANGE                       7
# USD INDEX - ICE FUTURES U.S.                                    7
# MICRO E-MINI S&P 500 INDEX - CHICAGO MERCANTILE EXCHANGE        7
# MICRO E-MINI NASDAQ-100 INDEX - CHICAGO MERCANTILE EXCHANGE     7
# MICRO BITCOIN - CHICAGO MERCANTILE EXCHANGE                     7
# MARINE FUEL OIL 0.5% FOB USGC - ICE FUTURES ENERGY DIV          7
# BITCOIN - CHICAGO MERCANTILE EXCHANGE                           7
# BRITISH POUND - CHICAGO MERCANTILE EXCHANGE                     7
# CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE                   7
# DOW JONES U.S. REAL ESTATE IDX - CHICAGO BOARD OF TRADE         7
# E-MINI S&P 500 - CHICAGO MERCANTILE EXCHANGE                    7
# ETHER CASH SETTLED - CHICAGO MERCANTILE EXCHANGE                7
# EURO FX - CHICAGO MERCANTILE EXCHANGE                           7
# EURO FX/BRITISH POUND XRATE - CHICAGO MERCANTILE EXCHANGE       7
# FUEL OIL-3% USGC/3.5% FOB RDAM - ICE FUTURES ENERGY DIV         7
# GOLD - COMMODITY EXCHANGE INC.                                  7
# GULF # 6 FUEL OIL CRACK - NEW YORK MERCANTILE EXCHANGE          7
# GULF JET NY HEAT OIL SPR - NEW YORK MERCANTILE EXCHANGE         7
# JAPANESE YEN - CHICAGO MERCANTILE EXCHANGE                      7
# WTI FINANCIAL CRUDE OIL - NEW YORK MERCANTILE EXCHANGE          7
# NORTH EURO HOT-ROLL COIL STEEL - COMMODITY EXCHANGE INC.        5
# DOGECOIN - LMX LABS LLC                                         3
# Name: count, dtype: int64

# %%
df.to_excel('cot.xlsx')

# %%
df[df['Market and Exchange Names']=='CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE']
# Out:
#                            Market and Exchange Names  \
# 11849  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11848  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11847  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11846  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11845  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11844  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11843  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11842  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11841  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11840  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11839  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11838  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11837  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11836  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11835  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11834  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11833  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11832  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11831  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11830  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11829  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11828  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11827  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11826  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11825  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11824  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11823  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11822  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11821  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11820  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11819  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11818  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11817  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11816  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11815  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11814  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11813  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11812  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11811  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11810  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11809  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11808  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11807  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11806  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11805  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11804  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 11803  CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
#
#       As of Date in Form YYYY-MM-DD  Noncommercial_net_positions  \
# 11849                    2024-01-02                        13590
# 11848                    2024-01-09                        13751
# 11847                    2024-01-16                        -6008
# 11846                    2024-01-23                         4937
# 11845                    2024-01-30                         6063
# 11844                    2024-02-06                        -5348
# 11843                    2024-02-13                         2254
# 11842                    2024-02-20                         4619
# 11841                    2024-02-27                         -515
# 11840                    2024-03-05                       -18459
# 11839                    2024-03-12                       -11037
# 11838                    2024-03-19                        -6274
# 11837                    2024-03-26                       -13142
# 11836                    2024-04-02                         -933
# 11835                    2024-04-09                        -2162
# 11834                    2024-04-16                       -29430
# 11833                    2024-04-23                         6365
# 11832                    2024-04-30                        13249
# 11831                    2024-05-07                        -6020
# 11830                    2024-05-14                       -11082
# 11829                    2024-05-21                       -10521
# 11828                    2024-05-28                         4239
# 11827                    2024-06-04                        -5054
# 11826                    2024-06-11                       -37854
# 11825                    2024-06-18                       -18438
# 11824                    2024-06-25                        25519
# 11823                    2024-07-02                         2060
# 11822                    2024-07-09                         9140
# 11821                    2024-07-16                       -21261
# 11820                    2024-07-23                       -29130
# 11819                    2024-07-30                       -34660
# 11818                    2024-08-06                        14631
# 11817                    2024-08-13                         2021
# 11816                    2024-08-20                        15201
# 11815                    2024-08-27                        54408
# 11814                    2024-09-03                        41458
# 11813                    2024-09-10                         -409
# 11812                    2024-09-17                        -4197
# 11811                    2024-09-24                         7561
# 11810                    2024-10-01                        -4414
# 11809                    2024-10-08                       -19148
# 11808                    2024-10-15                       -33242
# 11807                    2024-10-22                       -18238
# 11806                    2024-10-29                       -26868
# 11805                    2024-11-05                        -7730
# 11804                    2024-11-12                        -7160
# 11803                    2024-11-19                        -1177
#
#        Commercial_net_positions
# 11849                    -15628
# 11848                    -10107
# 11847                      6715
# 11846                     -1767
# 11845                     -7361
# 11844                      8612
# 11843                      2546
# 11842                     -5613
# 11841                     -1918
# 11840                     24140
# 11839                      6729
# 11838                     11141
# 11837                     13040
# 11836                     -1996
# 11835                      5859
# 11834                     33232
# 11833                     -7110
# 11832                    -13972
# 11831                      1355
# 11830                      6375
# 11829                     13637
# 11828                     -1504
# 11827                      9551
# 11826                     38157
# 11825                     20318
# 11824                    -32049
# 11823                     -1827
# 11822                    -11195
# 11821                     24271
# 11820                     31085
# 11819                     35122
# 11818                    -18348
# 11817                     -4480
# 11816                    -13952
# 11815                    -60862
# 11814                    -44131
# 11813                      4905
# 11812                      1143
# 11811                     -8315
# 11810                       422
# 11809                     26062
# 11808                     37676
# 11807                     24789
# 11806                     25571
# 11805                      6652
# 11804                     10414
# 11803                      -656
